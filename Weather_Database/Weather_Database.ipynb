# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import csv

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 710

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description" : city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san nicolas
# Processing Record 2 of Set 1 | salalah
# Processing Record 3 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | copiapo
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | ayan
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | lompoc
# Processing Record 11 of Set 1 | cubuk
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | dera din panah
# City not found. Skipping...
# Processing Record 14 of Set 1 | portland
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | chapleau
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | cidreira
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | sitka
# Processing Record 22 of Set 1 | mandalgovi
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | havelock
# Processing Record 25 of Set 1 | kumbo
# Processing Record 26 of Set 1 | nanortalik
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | luderitz
# Processing Record 29 of Set 1 | souillac
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | bukachacha
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | nkowakowa
# Processing Record 34 of Set 1 | sistranda
# Processing Record 35 of Set 1 | talnakh
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | mayo
# Processing Record 38 of Set 1 | vestmannaeyjar
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | codrington
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | srednekolymsk
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | kyren
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | evensk
# Processing Record 48 of Set 1 | taywarah
# Processing Record 49 of Set 1 | am timan
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | zlitan
# Processing Record 3 of Set 2 | ponta do sol
# Processing Record 4 of Set 2 | half moon bay
# Processing Record 5 of Set 2 | porbandar
# Processing Record 6 of Set 2 | hithadhoo
# Processing Record 7 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 8 of Set 2 | hun
# Processing Record 9 of Set 2 | mount isa
# Processing Record 10 of Set 2 | sao filipe
# Processing Record 11 of Set 2 | bowen
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | matara
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | tasiilaq
# Processing Record 17 of Set 2 | aksarka
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | kavieng
# Processing Record 20 of Set 2 | yuncheng
# Processing Record 21 of Set 2 | raudeberg
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | santa rita
# Processing Record 24 of Set 2 | mujiayingzi
# Processing Record 25 of Set 2 | saint-augustin
# Processing Record 26 of Set 2 | kaeo
# Processing Record 27 of Set 2 | rong kwang
# Processing Record 28 of Set 2 | aksay
# Processing Record 29 of Set 2 | benxi
# Processing Record 30 of Set 2 | chuy
# Processing Record 31 of Set 2 | kavaratti
# Processing Record 32 of Set 2 | solnechnyy
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | itarema
# Processing Record 35 of Set 2 | iqaluit
# Processing Record 36 of Set 2 | vestmanna
# Processing Record 37 of Set 2 | cherskiy
# Processing Record 38 of Set 2 | khatanga
# Processing Record 39 of Set 2 | vung tau
# Processing Record 40 of Set 2 | edd
# Processing Record 41 of Set 2 | rawson
# Processing Record 42 of Set 2 | san cristobal
# Processing Record 43 of Set 2 | atar
# Processing Record 44 of Set 2 | tiznit
# Processing Record 45 of Set 2 | lasa
# Processing Record 46 of Set 2 | victoria
# Processing Record 47 of Set 2 | nishihara
# Processing Record 48 of Set 2 | saint-francois
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 3 | urumqi
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | ko samui
# Processing Record 6 of Set 3 | kapaa
# Processing Record 7 of Set 3 | severo-kurilsk
# Processing Record 8 of Set 3 | tahe
# Processing Record 9 of Set 3 | komsomolskiy
# Processing Record 10 of Set 3 | tongchuan
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | qaanaaq
# Processing Record 13 of Set 3 | kayankulam
# Processing Record 14 of Set 3 | awjilah
# Processing Record 15 of Set 3 | hasaki
# Processing Record 16 of Set 3 | kuytun
# Processing Record 17 of Set 3 | benemerito de las americas
# Processing Record 18 of Set 3 | kichera
# Processing Record 19 of Set 3 | rieti
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | cabo san lucas
# Processing Record 22 of Set 3 | geraldton
# Processing Record 23 of Set 3 | vao
# Processing Record 24 of Set 3 | tongzi
# Processing Record 25 of Set 3 | beringovskiy
# Processing Record 26 of Set 3 | georgetown
# Processing Record 27 of Set 3 | asau
# Processing Record 28 of Set 3 | mahebourg
# Processing Record 29 of Set 3 | saint george
# Processing Record 30 of Set 3 | saint-pierre
# Processing Record 31 of Set 3 | kaitangata
# Processing Record 32 of Set 3 | udachnyy
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | cayenne
# Processing Record 35 of Set 3 | qaqortoq
# Processing Record 36 of Set 3 | hovd
# Processing Record 37 of Set 3 | leningradskiy
# Processing Record 38 of Set 3 | shanghai
# Processing Record 39 of Set 3 | horsham
# Processing Record 40 of Set 3 | great falls
# Processing Record 41 of Set 3 | saint-joseph
# Processing Record 42 of Set 3 | port alfred
# Processing Record 43 of Set 3 | boyle
# Processing Record 44 of Set 3 | fort nelson
# Processing Record 45 of Set 3 | payo
# Processing Record 46 of Set 3 | fredericksburg
# Processing Record 47 of Set 3 | bontang
# Processing Record 48 of Set 3 | mar del plata
# Processing Record 49 of Set 3 | mocuba
# Processing Record 50 of Set 3 | new norfolk
# Processing Record 1 of Set 4 | rio grande
# Processing Record 2 of Set 4 | auki
# Processing Record 3 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 4 | balkanabat
# Processing Record 5 of Set 4 | taoudenni
# Processing Record 6 of Set 4 | lebu
# Processing Record 7 of Set 4 | talcahuano
# Processing Record 8 of Set 4 | visnes
# Processing Record 9 of Set 4 | dikson
# Processing Record 10 of Set 4 | qianan
# Processing Record 11 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 4 | tomatlan
# Processing Record 13 of Set 4 | pashiya
# Processing Record 14 of Set 4 | kieta
# Processing Record 15 of Set 4 | vila franca do campo
# Processing Record 16 of Set 4 | calabozo
# Processing Record 17 of Set 4 | saldanha
# Processing Record 18 of Set 4 | port macquarie
# Processing Record 19 of Set 4 | nikolskoye
# Processing Record 20 of Set 4 | zhigansk
# Processing Record 21 of Set 4 | naze
# Processing Record 22 of Set 4 | lahij
# Processing Record 23 of Set 4 | lavrentiya
# Processing Record 24 of Set 4 | troitsko-pechorsk
# Processing Record 25 of Set 4 | upernavik
# Processing Record 26 of Set 4 | kruisfontein
# Processing Record 27 of Set 4 | bredasdorp
# Processing Record 28 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 4 | nouadhibou
# Processing Record 30 of Set 4 | torbay
# Processing Record 31 of Set 4 | omsukchan
# Processing Record 32 of Set 4 | fairbanks
# Processing Record 33 of Set 4 | yellowknife
# Processing Record 34 of Set 4 | los llanos de aridane
# Processing Record 35 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 4 | kataysk
# Processing Record 37 of Set 4 | hede
# Processing Record 38 of Set 4 | santa fe
# Processing Record 39 of Set 4 | manzhouli
# Processing Record 40 of Set 4 | siuna
# Processing Record 41 of Set 4 | severo-yeniseyskiy
# Processing Record 42 of Set 4 | east london
# Processing Record 43 of Set 4 | fort-shevchenko
# Processing Record 44 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 4 | moussoro
# Processing Record 46 of Set 4 | jian
# Processing Record 47 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 4 | tocopilla
# Processing Record 49 of Set 4 | devrek
# Processing Record 50 of Set 4 | katsuura
# Processing Record 1 of Set 5 | the valley
# Processing Record 2 of Set 5 | lubaczow
# Processing Record 3 of Set 5 | ahipara
# Processing Record 4 of Set 5 | teya
# Processing Record 5 of Set 5 | sao raimundo nonato
# Processing Record 6 of Set 5 | sabang
# Processing Record 7 of Set 5 | cam pha
# City not found. Skipping...
# Processing Record 8 of Set 5 | hellvik
# Processing Record 9 of Set 5 | hilo
# Processing Record 10 of Set 5 | nicoya
# Processing Record 11 of Set 5 | praya
# Processing Record 12 of Set 5 | berezovka
# Processing Record 13 of Set 5 | nantucket
# Processing Record 14 of Set 5 | kirensk
# Processing Record 15 of Set 5 | alice springs
# Processing Record 16 of Set 5 | bogorodskoye
# Processing Record 17 of Set 5 | cockburn town
# Processing Record 18 of Set 5 | corning
# Processing Record 19 of Set 5 | nome
# Processing Record 20 of Set 5 | laplace
# Processing Record 21 of Set 5 | wattegama
# Processing Record 22 of Set 5 | clyde river
# Processing Record 23 of Set 5 | outlook
# Processing Record 24 of Set 5 | piacabucu
# Processing Record 25 of Set 5 | kotaparh
# Processing Record 26 of Set 5 | muroto
# Processing Record 27 of Set 5 | progreso
# Processing Record 28 of Set 5 | zhangjiakou
# Processing Record 29 of Set 5 | carballo
# Processing Record 30 of Set 5 | pisco
# Processing Record 31 of Set 5 | kawalu
# Processing Record 32 of Set 5 | omboue
# Processing Record 33 of Set 5 | minudasht
# Processing Record 34 of Set 5 | peikang
# City not found. Skipping...
# Processing Record 35 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 36 of Set 5 | bethel
# Processing Record 37 of Set 5 | amahai
# Processing Record 38 of Set 5 | valdivia
# Processing Record 39 of Set 5 | opuwo
# Processing Record 40 of Set 5 | eirunepe
# Processing Record 41 of Set 5 | artyom
# Processing Record 42 of Set 5 | dakar
# Processing Record 43 of Set 5 | mount gambier
# Processing Record 44 of Set 5 | ulladulla
# Processing Record 45 of Set 5 | esmeralda
# Processing Record 46 of Set 5 | glendive
# Processing Record 47 of Set 5 | anadyr
# Processing Record 48 of Set 5 | norfolk
# Processing Record 49 of Set 5 | honiara
# Processing Record 50 of Set 5 | velez-malaga
# Processing Record 1 of Set 6 | constitucion
# Processing Record 2 of Set 6 | brits
# Processing Record 3 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 6 | bathurst
# Processing Record 5 of Set 6 | padilla
# Processing Record 6 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 6 | soroti
# Processing Record 8 of Set 6 | shingu
# Processing Record 9 of Set 6 | meulaboh
# Processing Record 10 of Set 6 | trelew
# Processing Record 11 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 6 | monteprandone
# Processing Record 13 of Set 6 | culebra
# Processing Record 14 of Set 6 | zyryanka
# Processing Record 15 of Set 6 | mapastepec
# Processing Record 16 of Set 6 | murayama
# Processing Record 17 of Set 6 | tura
# Processing Record 18 of Set 6 | isla aguada
# Processing Record 19 of Set 6 | la fria
# Processing Record 20 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 21 of Set 6 | burnie
# Processing Record 22 of Set 6 | toropets
# Processing Record 23 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 6 | sumbawanga
# Processing Record 25 of Set 6 | dilla
# Processing Record 26 of Set 6 | uyovu
# Processing Record 27 of Set 6 | grand gaube
# Processing Record 28 of Set 6 | te anau
# Processing Record 29 of Set 6 | norman wells
# Processing Record 30 of Set 6 | skibbereen
# Processing Record 31 of Set 6 | sur
# Processing Record 32 of Set 6 | lagoa
# Processing Record 33 of Set 6 | springbok
# Processing Record 34 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 36 of Set 6 | abu samrah
# Processing Record 37 of Set 6 | martapura
# Processing Record 38 of Set 6 | glenwood springs
# Processing Record 39 of Set 6 | chernyshevskiy
# Processing Record 40 of Set 6 | lisakovsk
# Processing Record 41 of Set 6 | qandala
# Processing Record 42 of Set 6 | aquiraz
# Processing Record 43 of Set 6 | klaksvik
# Processing Record 44 of Set 6 | mortka
# Processing Record 45 of Set 6 | hamilton
# Processing Record 46 of Set 6 | laguna
# Processing Record 47 of Set 6 | chupa
# Processing Record 48 of Set 6 | nelson bay
# Processing Record 49 of Set 6 | lethem
# Processing Record 50 of Set 6 | tarakan
# Processing Record 1 of Set 7 | pogranichnyy
# Processing Record 2 of Set 7 | qasigiannguit
# Processing Record 3 of Set 7 | narsaq
# Processing Record 4 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 5 of Set 7 | pokhara
# Processing Record 6 of Set 7 | port elizabeth
# Processing Record 7 of Set 7 | sao joaquim
# Processing Record 8 of Set 7 | baykit
# Processing Record 9 of Set 7 | faanui
# Processing Record 10 of Set 7 | bambanglipuro
# Processing Record 11 of Set 7 | amuntai
# Processing Record 12 of Set 7 | poum
# Processing Record 13 of Set 7 | grindavik
# Processing Record 14 of Set 7 | davila
# Processing Record 15 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 17 of Set 7 | yanam
# Processing Record 18 of Set 7 | ucluelet
# Processing Record 19 of Set 7 | airai
# Processing Record 20 of Set 7 | miandrivazo
# Processing Record 21 of Set 7 | salta
# Processing Record 22 of Set 7 | barcelona
# Processing Record 23 of Set 7 | den helder
# Processing Record 24 of Set 7 | foam lake
# Processing Record 25 of Set 7 | hami
# Processing Record 26 of Set 7 | kalmunai
# Processing Record 27 of Set 7 | cuamba
# Processing Record 28 of Set 7 | hrubieszow
# Processing Record 29 of Set 7 | palana
# Processing Record 30 of Set 7 | jingdezhen
# Processing Record 31 of Set 7 | bengkulu
# Processing Record 32 of Set 7 | divo
# Processing Record 33 of Set 7 | pevek
# Processing Record 34 of Set 7 | gravdal
# Processing Record 35 of Set 7 | vanimo
# Processing Record 36 of Set 7 | dole
# Processing Record 37 of Set 7 | katghora
# Processing Record 38 of Set 7 | nizhnyaya omka
# Processing Record 39 of Set 7 | egvekinot
# Processing Record 40 of Set 7 | san patricio
# Processing Record 41 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 42 of Set 7 | sesheke
# Processing Record 43 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 45 of Set 7 | pattukkottai
# Processing Record 46 of Set 7 | barguzin
# Processing Record 47 of Set 7 | bahia blanca
# Processing Record 48 of Set 7 | athabasca
# Processing Record 49 of Set 7 | watsa
# Processing Record 50 of Set 7 | macamic
# Processing Record 1 of Set 8 | inongo
# Processing Record 2 of Set 8 | marsh harbour
# Processing Record 3 of Set 8 | lieto
# Processing Record 4 of Set 8 | burica
# City not found. Skipping...
# Processing Record 5 of Set 8 | almas
# Processing Record 6 of Set 8 | taltal
# Processing Record 7 of Set 8 | banda aceh
# Processing Record 8 of Set 8 | orje
# Processing Record 9 of Set 8 | ossora
# Processing Record 10 of Set 8 | bathsheba
# Processing Record 11 of Set 8 | guerrero negro
# Processing Record 12 of Set 8 | rock sound
# Processing Record 13 of Set 8 | yerbogachen
# Processing Record 14 of Set 8 | port augusta
# Processing Record 15 of Set 8 | eenhana
# Processing Record 16 of Set 8 | bella union
# Processing Record 17 of Set 8 | griffith
# Processing Record 18 of Set 8 | saint-denis
# Processing Record 19 of Set 8 | luwuk
# Processing Record 20 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 8 | avera
# Processing Record 22 of Set 8 | dubbo
# Processing Record 23 of Set 8 | hrebinka
# Processing Record 24 of Set 8 | sibolga
# Processing Record 25 of Set 8 | timra
# Processing Record 26 of Set 8 | kushiro
# Processing Record 27 of Set 8 | mayor pablo lagerenza
# Processing Record 28 of Set 8 | cururupu
# Processing Record 29 of Set 8 | kasempa
# Processing Record 30 of Set 8 | linhares
# Processing Record 31 of Set 8 | igrim
# Processing Record 32 of Set 8 | hargeysa
# Processing Record 33 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 34 of Set 8 | arman
# Processing Record 35 of Set 8 | dunedin
# Processing Record 36 of Set 8 | fomboni
# Processing Record 37 of Set 8 | ouadda
# Processing Record 38 of Set 8 | ural
# Processing Record 39 of Set 8 | homer
# Processing Record 40 of Set 8 | kirkland lake
# Processing Record 41 of Set 8 | santo antonio do ica
# Processing Record 42 of Set 8 | lunenburg
# Processing Record 43 of Set 8 | dukat
# Processing Record 44 of Set 8 | port lincoln
# Processing Record 45 of Set 8 | namatanai
# Processing Record 46 of Set 8 | muscat
# Processing Record 47 of Set 8 | soe
# Processing Record 48 of Set 8 | kiama
# Processing Record 49 of Set 8 | alappuzha
# Processing Record 50 of Set 8 | iskateley
# Processing Record 1 of Set 9 | hobyo
# Processing Record 2 of Set 9 | rognan
# Processing Record 3 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 9 | port blair
# Processing Record 5 of Set 9 | hofn
# Processing Record 6 of Set 9 | marion
# Processing Record 7 of Set 9 | mitu
# Processing Record 8 of Set 9 | bayan
# Processing Record 9 of Set 9 | roald
# Processing Record 10 of Set 9 | beira
# Processing Record 11 of Set 9 | darhan
# Processing Record 12 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 9 | ilulissat
# Processing Record 14 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 9 | coos bay
# Processing Record 16 of Set 9 | surgut
# Processing Record 17 of Set 9 | houston
# Processing Record 18 of Set 9 | pasni
# Processing Record 19 of Set 9 | mecca
# Processing Record 20 of Set 9 | hay river
# Processing Record 21 of Set 9 | buala
# Processing Record 22 of Set 9 | kajaani
# Processing Record 23 of Set 9 | huarmey
# Processing Record 24 of Set 9 | chadan
# Processing Record 25 of Set 9 | melo
# Processing Record 26 of Set 9 | birao
# Processing Record 27 of Set 9 | puerto madryn
# Processing Record 28 of Set 9 | turan
# Processing Record 29 of Set 9 | tabou
# Processing Record 30 of Set 9 | othonoi
# City not found. Skipping...
# Processing Record 31 of Set 9 | arzamas
# Processing Record 32 of Set 9 | north bend
# Processing Record 33 of Set 9 | dauriya
# Processing Record 34 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 35 of Set 9 | itoman
# Processing Record 36 of Set 9 | berdyuzhye
# City not found. Skipping...
# Processing Record 37 of Set 9 | pangnirtung
# Processing Record 38 of Set 9 | tuatapere
# Processing Record 39 of Set 9 | tatawin
# Processing Record 40 of Set 9 | naryan-mar
# Processing Record 41 of Set 9 | muriti
# Processing Record 42 of Set 9 | derzhavinsk
# Processing Record 43 of Set 9 | bambous virieux
# Processing Record 44 of Set 9 | polloc
# Processing Record 45 of Set 9 | dingle
# Processing Record 46 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 9 | ulety
# Processing Record 48 of Set 9 | porto de moz
# Processing Record 49 of Set 9 | ajdabiya
# Processing Record 50 of Set 9 | launceston
# Processing Record 1 of Set 10 | thinadhoo
# Processing Record 2 of Set 10 | atambua
# Processing Record 3 of Set 10 | marv dasht
# City not found. Skipping...
# Processing Record 4 of Set 10 | la ronge
# Processing Record 5 of Set 10 | hirara
# Processing Record 6 of Set 10 | paita
# Processing Record 7 of Set 10 | valley city
# Processing Record 8 of Set 10 | bonavista
# Processing Record 9 of Set 10 | kutina
# Processing Record 10 of Set 10 | chapais
# Processing Record 11 of Set 10 | san quintin
# Processing Record 12 of Set 10 | vardo
# Processing Record 13 of Set 10 | karratha
# Processing Record 14 of Set 10 | bojnurd
# Processing Record 15 of Set 10 | northam
# Processing Record 16 of Set 10 | colares
# Processing Record 17 of Set 10 | korem
# Processing Record 18 of Set 10 | conceicao do araguaia
# Processing Record 19 of Set 10 | mitsamiouli
# Processing Record 20 of Set 10 | coquimbo
# Processing Record 21 of Set 10 | santa barbara
# Processing Record 22 of Set 10 | linchuan
# City not found. Skipping...
# Processing Record 23 of Set 10 | vostok
# Processing Record 24 of Set 10 | gunjur
# Processing Record 25 of Set 10 | lufilufi
# Processing Record 26 of Set 10 | havoysund
# Processing Record 27 of Set 10 | santa maria
# Processing Record 28 of Set 10 | sechura
# Processing Record 29 of Set 10 | nara
# Processing Record 30 of Set 10 | kinablangan
# Processing Record 31 of Set 10 | ginda
# Processing Record 32 of Set 10 | endirey
# Processing Record 33 of Set 10 | novikovo
# Processing Record 34 of Set 10 | viru
# Processing Record 35 of Set 10 | can
# Processing Record 36 of Set 10 | saint anthony
# Processing Record 37 of Set 10 | goderich
# Processing Record 38 of Set 10 | lixourion
# Processing Record 39 of Set 10 | yaval
# Processing Record 40 of Set 10 | gawler
# Processing Record 41 of Set 10 | isangel
# Processing Record 42 of Set 10 | aklavik
# Processing Record 43 of Set 10 | bilibino
# Processing Record 44 of Set 10 | katha
# City not found. Skipping...
# Processing Record 45 of Set 10 | mwense
# Processing Record 46 of Set 10 | neiafu
# Processing Record 47 of Set 10 | noumea
# Processing Record 48 of Set 10 | beloha
# Processing Record 49 of Set 10 | kenora
# Processing Record 50 of Set 10 | flinders
# Processing Record 1 of Set 11 | andros town
# Processing Record 2 of Set 11 | roebourne
# Processing Record 3 of Set 11 | aksu
# Processing Record 4 of Set 11 | ferrol
# Processing Record 5 of Set 11 | marrakesh
# Processing Record 6 of Set 11 | palmares do sul
# Processing Record 7 of Set 11 | akyab
# Processing Record 8 of Set 11 | vila velha
# Processing Record 9 of Set 11 | santiago
# Processing Record 10 of Set 11 | farmos
# Processing Record 11 of Set 11 | tarashcha
# Processing Record 12 of Set 11 | kiunga
# Processing Record 13 of Set 11 | dzialdowo
# Processing Record 14 of Set 11 | mizdah
# Processing Record 15 of Set 11 | berlevag
# Processing Record 16 of Set 11 | takoradi
# Processing Record 17 of Set 11 | alyangula
# Processing Record 18 of Set 11 | kita
# Processing Record 19 of Set 11 | fernandina beach
# Processing Record 20 of Set 11 | cabedelo
# Processing Record 21 of Set 11 | ratnagiri
# Processing Record 22 of Set 11 | iquitos
# Processing Record 23 of Set 11 | yichang
# Processing Record 24 of Set 11 | slave lake
# Processing Record 25 of Set 11 | velsk
# Processing Record 26 of Set 11 | gorgan
# Processing Record 27 of Set 11 | matagami
# Processing Record 28 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 29 of Set 11 | jibuti
# Processing Record 30 of Set 11 | bedesa
# Processing Record 31 of Set 11 | xuddur
# Processing Record 32 of Set 11 | kitimat
# Processing Record 33 of Set 11 | gizo
# Processing Record 34 of Set 11 | doka
# Processing Record 35 of Set 11 | kindersley
# Processing Record 36 of Set 11 | susangerd
# Processing Record 37 of Set 11 | cuautepec
# Processing Record 38 of Set 11 | grand island
# Processing Record 39 of Set 11 | krasnoselkup
# Processing Record 40 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 11 | brebes
# Processing Record 42 of Set 11 | mae ramat
# Processing Record 43 of Set 11 | sinnamary
# Processing Record 44 of Set 11 | nova olimpia
# Processing Record 45 of Set 11 | nata
# Processing Record 46 of Set 11 | bayangol
# Processing Record 47 of Set 11 | bandarbeyla
# Processing Record 48 of Set 11 | bilma
# Processing Record 49 of Set 11 | eragny
# Processing Record 50 of Set 11 | umm kaddadah
# Processing Record 1 of Set 12 | tawau
# Processing Record 2 of Set 12 | fortuna
# Processing Record 3 of Set 12 | broome
# Processing Record 4 of Set 12 | mokrousovo
# Processing Record 5 of Set 12 | belyy yar
# Processing Record 6 of Set 12 | gumdag
# Processing Record 7 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 12 | tromso
# Processing Record 9 of Set 12 | ketchikan
# Processing Record 10 of Set 12 | harper
# Processing Record 11 of Set 12 | khandyga
# Processing Record 12 of Set 12 | yarada
# Processing Record 13 of Set 12 | suntar
# Processing Record 14 of Set 12 | ilam
# Processing Record 15 of Set 12 | gayny
# Processing Record 16 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 17 of Set 12 | bonfim
# Processing Record 18 of Set 12 | salamiyah
# Processing Record 19 of Set 12 | alofi
# Processing Record 20 of Set 12 | florianopolis
# Processing Record 21 of Set 12 | tirupati
# Processing Record 22 of Set 12 | zlatograd
# Processing Record 23 of Set 12 | mareeba
# Processing Record 24 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 25 of Set 12 | tecolutla
# Processing Record 26 of Set 12 | lao cai
# Processing Record 27 of Set 12 | sioux lookout
# Processing Record 28 of Set 12 | verkhnevilyuysk
# Processing Record 29 of Set 12 | baoqing
# Processing Record 30 of Set 12 | la solana
# Processing Record 31 of Set 12 | sarangani
# Processing Record 32 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 33 of Set 12 | valparaiso
# Processing Record 34 of Set 12 | redmond
# Processing Record 35 of Set 12 | upington
# Processing Record 36 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 12 | muzhi
# Processing Record 38 of Set 12 | chunhuhub
# Processing Record 39 of Set 12 | okato
# Processing Record 40 of Set 12 | marienburg
# Processing Record 41 of Set 12 | fare
# Processing Record 42 of Set 12 | visakhapatnam
# Processing Record 43 of Set 12 | ambulu
# Processing Record 44 of Set 12 | kivsharivka
# Processing Record 45 of Set 12 | khromtau
# Processing Record 46 of Set 12 | shu
# Processing Record 47 of Set 12 | sorong
# Processing Record 48 of Set 12 | coolum beach
# Processing Record 49 of Set 12 | pacific grove
# Processing Record 50 of Set 12 | onguday
# Processing Record 1 of Set 13 | port-gentil
# Processing Record 2 of Set 13 | tautira
# Processing Record 3 of Set 13 | sawakin
# Processing Record 4 of Set 13 | monster
# Processing Record 5 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 6 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 7 of Set 13 | kambove
# Processing Record 8 of Set 13 | antofagasta
# Processing Record 9 of Set 13 | svetlyy
# Processing Record 10 of Set 13 | unye
# City not found. Skipping...
# Processing Record 11 of Set 13 | sisimiut
# Processing Record 12 of Set 13 | scalloway
# City not found. Skipping...
# Processing Record 13 of Set 13 | dinar
# Processing Record 14 of Set 13 | yulara
# Processing Record 15 of Set 13 | kudahuvadhoo
# Processing Record 16 of Set 13 | saint-georges
# Processing Record 17 of Set 13 | cedar city
# Processing Record 18 of Set 13 | vera cruz
# Processing Record 19 of Set 13 | durg
# Processing Record 20 of Set 13 | sira
# Processing Record 21 of Set 13 | curuca
# Processing Record 22 of Set 13 | cabo rojo
# Processing Record 23 of Set 13 | tarko-sale
# Processing Record 24 of Set 13 | ancud
# Processing Record 25 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 26 of Set 13 | xinglongshan
# Processing Record 27 of Set 13 | koslan
# Processing Record 28 of Set 13 | dalvik
# Processing Record 29 of Set 13 | mananara
# Processing Record 30 of Set 13 | moranbah
# Processing Record 31 of Set 13 | boyolangu
# Processing Record 32 of Set 13 | songea
# Processing Record 33 of Set 13 | leh
# Processing Record 34 of Set 13 | bullhead city
# Processing Record 35 of Set 13 | remontnoye
# Processing Record 36 of Set 13 | kulhudhuffushi
# Processing Record 37 of Set 13 | scarborough
# Processing Record 38 of Set 13 | nurlat
# Processing Record 39 of Set 13 | camacha
# Processing Record 40 of Set 13 | biak
# Processing Record 41 of Set 13 | pochutla
# Processing Record 42 of Set 13 | maragogi
# Processing Record 43 of Set 13 | verkhnetulomskiy
# Processing Record 44 of Set 13 | algiers
# Processing Record 45 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 13 | churapcha
# Processing Record 47 of Set 13 | port hedland
# Processing Record 48 of Set 13 | safford
# Processing Record 49 of Set 13 | cahors
# Processing Record 50 of Set 13 | los palacios
# Processing Record 1 of Set 14 | namibe
# Processing Record 2 of Set 14 | farah
# Processing Record 3 of Set 14 | muros
# Processing Record 4 of Set 14 | turayf
# Processing Record 5 of Set 14 | sao joao evangelista
# Processing Record 6 of Set 14 | kismayo
# Processing Record 7 of Set 14 | touros
# Processing Record 8 of Set 14 | kutum
# Processing Record 9 of Set 14 | minbu
# Processing Record 10 of Set 14 | berezovyy
# Processing Record 11 of Set 14 | plerin
# Processing Record 12 of Set 14 | saucillo
# Processing Record 13 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 14 | tornio
# Processing Record 15 of Set 14 | amqui
# Processing Record 16 of Set 14 | sciacca
# Processing Record 17 of Set 14 | san felipe
# Processing Record 18 of Set 14 | jinchang
# Processing Record 19 of Set 14 | bhum
# Processing Record 20 of Set 14 | komadi
# Processing Record 21 of Set 14 | pavilosta
# Processing Record 22 of Set 14 | milkovo
# Processing Record 23 of Set 14 | walvis bay
# Processing Record 24 of Set 14 | mantua
# Processing Record 25 of Set 14 | tongren
# Processing Record 26 of Set 14 | ondjiva
# Processing Record 27 of Set 14 | marsabit
# Processing Record 28 of Set 14 | zaysan
# Processing Record 29 of Set 14 | luau
# Processing Record 30 of Set 14 | labuhan
# Processing Record 31 of Set 14 | swan hill
# Processing Record 32 of Set 14 | volnovakha
# Processing Record 33 of Set 14 | mindelo
# Processing Record 34 of Set 14 | tucupita
# Processing Record 35 of Set 14 | wadi maliz
# Processing Record 36 of Set 14 | ayagoz
# Processing Record 37 of Set 14 | cabra
# Processing Record 38 of Set 14 | ereymentau
# Processing Record 39 of Set 14 | denpasar
# Processing Record 40 of Set 14 | poso
# Processing Record 41 of Set 14 | tukrah
# Processing Record 42 of Set 14 | labytnangi
# Processing Record 43 of Set 14 | kindu
# Processing Record 44 of Set 14 | ngunguru
# Processing Record 45 of Set 14 | sorland
# Processing Record 46 of Set 14 | beysehir
# Processing Record 47 of Set 14 | ukiah
# Processing Record 48 of Set 14 | south venice
# Processing Record 49 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 14 | puerto escondido
# Processing Record 1 of Set 15 | arica
# Processing Record 2 of Set 15 | praia da vitoria
# Processing Record 3 of Set 15 | misratah
# Processing Record 4 of Set 15 | kikuchi
# Processing Record 5 of Set 15 | magadi
# Processing Record 6 of Set 15 | gornopravdinsk
# Processing Record 7 of Set 15 | svetlogorsk
# Processing Record 8 of Set 15 | lakes entrance
# Processing Record 9 of Set 15 | abilene
# Processing Record 10 of Set 15 | skjervoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 654

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  San Nicolas  18.1725  120.5953     79.79        58          41       15.37
# 1      Salalah  17.0151   54.0924     69.89        35           0       12.66
# 2       Albany  42.6001  -73.9662     41.27        78         100        5.77
# 3      Copiapo -27.3667  -70.3333     56.89        75           2        2.57
# 4      Mataura -46.1927  168.8643     72.48        60         100        5.17
# 5         Ayan  56.4500  138.1667     -5.84        64          97       13.96
# 6   Chokurdakh  70.6333  147.9167    -22.70        97         100        7.96
# 7    Cape Town -33.9258   18.4232     68.38        60          81       14.00
# 8       Lompoc  34.6391 -120.4579     48.02        81          81        5.99
# 9        Cubuk  40.2386   33.0322     30.76        69          75        1.14
#
#   Country       Description
# 0      PH  scattered clouds
# 1      OM         clear sky
# 2      US   overcast clouds
# 3      CL         clear sky
# 4      NZ   overcast clouds
# 5      RU   overcast clouds
# 6      RU   overcast clouds
# 7      ZA     broken clouds
# 8      US     broken clouds
# 9      TR     broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Description"] 

# Recreate the DataFrame by using the new column order

city_data_df = city_data_df[new_column_order]


# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  San Nicolas      PH  18.1725  120.5953     79.79        58          41
# 1      Salalah      OM  17.0151   54.0924     69.89        35           0
# 2       Albany      US  42.6001  -73.9662     41.27        78         100
# 3      Copiapo      CL -27.3667  -70.3333     56.89        75           2
# 4      Mataura      NZ -46.1927  168.8643     72.48        60         100
# 5         Ayan      RU  56.4500  138.1667     -5.84        64          97
# 6   Chokurdakh      RU  70.6333  147.9167    -22.70        97         100
# 7    Cape Town      ZA -33.9258   18.4232     68.38        60          81
# 8       Lompoc      US  34.6391 -120.4579     48.02        81          81
# 9        Cubuk      TR  40.2386   33.0322     30.76        69          75
#
#    Wind Speed       Description
# 0       15.37  scattered clouds
# 1       12.66         clear sky
# 2        5.77   overcast clouds
# 3        2.57         clear sky
# 4        5.17   overcast clouds
# 5       13.96   overcast clouds
# 6        7.96   overcast clouds
# 7       14.00     broken clouds
# 8        5.99     broken clouds
# 9        1.14     broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
