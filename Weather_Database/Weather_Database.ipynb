# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import csv

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 732

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description" : city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | tarakan
# Processing Record 3 of Set 1 | azimur
# City not found. Skipping...
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | haines junction
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | kruisfontein
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | thompson
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | esperance
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | luderitz
# Processing Record 19 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | hamburg
# Processing Record 22 of Set 1 | poum
# Processing Record 23 of Set 1 | dunedin
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | vestmannaeyjar
# Processing Record 26 of Set 1 | provideniya
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | clarksburg
# Processing Record 31 of Set 1 | grindavik
# Processing Record 32 of Set 1 | ballina
# Processing Record 33 of Set 1 | calama
# Processing Record 34 of Set 1 | pisco
# Processing Record 35 of Set 1 | lufilufi
# Processing Record 36 of Set 1 | groton
# Processing Record 37 of Set 1 | beringovskiy
# Processing Record 38 of Set 1 | gaillac
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | bilciuresti
# Processing Record 41 of Set 1 | le port
# Processing Record 42 of Set 1 | bonavista
# Processing Record 43 of Set 1 | anadyr
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | durban
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | launceston
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | sug-aksy
# City not found. Skipping...
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | hofn
# Processing Record 2 of Set 2 | bluff
# Processing Record 3 of Set 2 | khatanga
# Processing Record 4 of Set 2 | hasaki
# Processing Record 5 of Set 2 | dalvik
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | yatou
# Processing Record 8 of Set 2 | cap malheureux
# Processing Record 9 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 2 | georgetown
# Processing Record 11 of Set 2 | bonthe
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | chillicothe
# Processing Record 14 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 2 | gazanjyk
# Processing Record 16 of Set 2 | gold coast
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | rosetown
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | hamilton
# Processing Record 22 of Set 2 | portland
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | kjollefjord
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | narsaq
# Processing Record 27 of Set 2 | ixtapa
# Processing Record 28 of Set 2 | dauphin
# Processing Record 29 of Set 2 | quesnel
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | yerbogachen
# Processing Record 33 of Set 2 | mae hong son
# Processing Record 34 of Set 2 | college
# Processing Record 35 of Set 2 | caravelas
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | yazd
# Processing Record 40 of Set 2 | pontianak
# Processing Record 41 of Set 2 | leningradskiy
# Processing Record 42 of Set 2 | patos
# Processing Record 43 of Set 2 | sinnamary
# Processing Record 44 of Set 2 | ust-maya
# Processing Record 45 of Set 2 | codrington
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | birin
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | panguipulli
# Processing Record 50 of Set 2 | kon tum
# Processing Record 1 of Set 3 | vila franca do campo
# Processing Record 2 of Set 3 | mizpe ramon
# City not found. Skipping...
# Processing Record 3 of Set 3 | kodiak
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | nome
# Processing Record 6 of Set 3 | znamenskoye
# Processing Record 7 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | bull savanna
# Processing Record 10 of Set 3 | port elizabeth
# Processing Record 11 of Set 3 | acapulco
# Processing Record 12 of Set 3 | pochutla
# Processing Record 13 of Set 3 | bhum
# Processing Record 14 of Set 3 | hilo
# Processing Record 15 of Set 3 | vermillion
# Processing Record 16 of Set 3 | evensk
# Processing Record 17 of Set 3 | faanui
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | dhangadhi
# Processing Record 20 of Set 3 | brigantine
# Processing Record 21 of Set 3 | norman wells
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | kathmandu
# Processing Record 24 of Set 3 | mumford
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | kavieng
# Processing Record 27 of Set 3 | coihaique
# Processing Record 28 of Set 3 | mananara
# Processing Record 29 of Set 3 | mouzakion
# City not found. Skipping...
# Processing Record 30 of Set 3 | yar-sale
# Processing Record 31 of Set 3 | mutata
# Processing Record 32 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 3 | rocha
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 3 | bom jesus
# Processing Record 37 of Set 3 | hovd
# Processing Record 38 of Set 3 | hadgaon
# Processing Record 39 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 3 | igarka
# Processing Record 41 of Set 3 | inuvik
# Processing Record 42 of Set 3 | lebu
# Processing Record 43 of Set 3 | constitucion
# Processing Record 44 of Set 3 | acri
# Processing Record 45 of Set 3 | cabo san lucas
# Processing Record 46 of Set 3 | salalah
# Processing Record 47 of Set 3 | simbahan
# Processing Record 48 of Set 3 | souillac
# Processing Record 49 of Set 3 | ayan
# Processing Record 50 of Set 3 | kpandu
# Processing Record 1 of Set 4 | chernyatyn
# Processing Record 2 of Set 4 | longyearbyen
# Processing Record 3 of Set 4 | alofi
# Processing Record 4 of Set 4 | ancud
# Processing Record 5 of Set 4 | upernavik
# Processing Record 6 of Set 4 | celestun
# Processing Record 7 of Set 4 | mezen
# Processing Record 8 of Set 4 | labrea
# Processing Record 9 of Set 4 | sabha
# Processing Record 10 of Set 4 | prince rupert
# Processing Record 11 of Set 4 | balaka
# Processing Record 12 of Set 4 | loandjili
# Processing Record 13 of Set 4 | darhan
# Processing Record 14 of Set 4 | ajdabiya
# Processing Record 15 of Set 4 | ilulissat
# Processing Record 16 of Set 4 | shache
# Processing Record 17 of Set 4 | puerto escondido
# Processing Record 18 of Set 4 | castro
# Processing Record 19 of Set 4 | gamba
# Processing Record 20 of Set 4 | tilichiki
# Processing Record 21 of Set 4 | masuguru
# Processing Record 22 of Set 4 | puerto colombia
# Processing Record 23 of Set 4 | kavaratti
# Processing Record 24 of Set 4 | bathsheba
# Processing Record 25 of Set 4 | requena
# Processing Record 26 of Set 4 | inhambane
# Processing Record 27 of Set 4 | suicheng
# Processing Record 28 of Set 4 | deputatskiy
# Processing Record 29 of Set 4 | zhuanghe
# Processing Record 30 of Set 4 | okhtyrka
# Processing Record 31 of Set 4 | adrar
# Processing Record 32 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 4 | torbay
# Processing Record 34 of Set 4 | jaguarao
# Processing Record 35 of Set 4 | pemangkat
# Processing Record 36 of Set 4 | rondonopolis
# Processing Record 37 of Set 4 | port lincoln
# Processing Record 38 of Set 4 | cockburn town
# Processing Record 39 of Set 4 | ust-nera
# Processing Record 40 of Set 4 | araouane
# Processing Record 41 of Set 4 | mao
# Processing Record 42 of Set 4 | asau
# Processing Record 43 of Set 4 | santo antonio do amparo
# Processing Record 44 of Set 4 | killybegs
# Processing Record 45 of Set 4 | atyrau
# Processing Record 46 of Set 4 | geraldton
# Processing Record 47 of Set 4 | basco
# Processing Record 48 of Set 4 | wanxian
# Processing Record 49 of Set 4 | winsum
# Processing Record 50 of Set 4 | carnarvon
# Processing Record 1 of Set 5 | segou
# Processing Record 2 of Set 5 | mehamn
# Processing Record 3 of Set 5 | uk
# City not found. Skipping...
# Processing Record 4 of Set 5 | olinda
# Processing Record 5 of Set 5 | palmer
# Processing Record 6 of Set 5 | katsuura
# Processing Record 7 of Set 5 | alegrete
# Processing Record 8 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 5 | jibuti
# Processing Record 10 of Set 5 | makakilo city
# Processing Record 11 of Set 5 | nikolskoye
# Processing Record 12 of Set 5 | la ronge
# Processing Record 13 of Set 5 | bethel
# Processing Record 14 of Set 5 | zhuhai
# Processing Record 15 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 5 | nanortalik
# Processing Record 17 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 18 of Set 5 | saskylakh
# Processing Record 19 of Set 5 | quang ngai
# Processing Record 20 of Set 5 | beira
# Processing Record 21 of Set 5 | chokurdakh
# Processing Record 22 of Set 5 | toora-khem
# Processing Record 23 of Set 5 | sajanan
# Processing Record 24 of Set 5 | kitgum
# Processing Record 25 of Set 5 | kyabe
# Processing Record 26 of Set 5 | kholodnyy
# Processing Record 27 of Set 5 | borama
# City not found. Skipping...
# Processing Record 28 of Set 5 | pevek
# Processing Record 29 of Set 5 | riyadh
# Processing Record 30 of Set 5 | socorro
# Processing Record 31 of Set 5 | buala
# Processing Record 32 of Set 5 | frederikshavn
# Processing Record 33 of Set 5 | taoudenni
# Processing Record 34 of Set 5 | imeni poliny osipenko
# Processing Record 35 of Set 5 | athabasca
# Processing Record 36 of Set 5 | dali
# Processing Record 37 of Set 5 | severobaykalsk
# Processing Record 38 of Set 5 | silver city
# Processing Record 39 of Set 5 | sisimiut
# Processing Record 40 of Set 5 | dhidhdhoo
# Processing Record 41 of Set 5 | kenai
# Processing Record 42 of Set 5 | dongsheng
# Processing Record 43 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 5 | san antonio
# Processing Record 45 of Set 5 | quatre cocos
# Processing Record 46 of Set 5 | cayenne
# Processing Record 47 of Set 5 | naze
# Processing Record 48 of Set 5 | storforshei
# Processing Record 49 of Set 5 | sao felix do xingu
# Processing Record 50 of Set 5 | cabedelo
# Processing Record 1 of Set 6 | maniitsoq
# Processing Record 2 of Set 6 | qaanaaq
# Processing Record 3 of Set 6 | verkhnyaya inta
# Processing Record 4 of Set 6 | mbaiki
# Processing Record 5 of Set 6 | saint george
# Processing Record 6 of Set 6 | namibe
# Processing Record 7 of Set 6 | floro
# Processing Record 8 of Set 6 | cimislia
# Processing Record 9 of Set 6 | salym
# Processing Record 10 of Set 6 | ubinskoye
# Processing Record 11 of Set 6 | gravdal
# Processing Record 12 of Set 6 | praia da vitoria
# Processing Record 13 of Set 6 | abeche
# Processing Record 14 of Set 6 | sur
# Processing Record 15 of Set 6 | bilibino
# Processing Record 16 of Set 6 | dwarka
# Processing Record 17 of Set 6 | guerrero negro
# Processing Record 18 of Set 6 | port said
# Processing Record 19 of Set 6 | half moon bay
# Processing Record 20 of Set 6 | mapastepec
# Processing Record 21 of Set 6 | abilene
# Processing Record 22 of Set 6 | berlevag
# Processing Record 23 of Set 6 | pacific grove
# Processing Record 24 of Set 6 | ust-omchug
# Processing Record 25 of Set 6 | zhob
# Processing Record 26 of Set 6 | dukat
# Processing Record 27 of Set 6 | havre-saint-pierre
# Processing Record 28 of Set 6 | xining
# Processing Record 29 of Set 6 | guozhen
# Processing Record 30 of Set 6 | honningsvag
# Processing Record 31 of Set 6 | kaitangata
# Processing Record 32 of Set 6 | kahului
# Processing Record 33 of Set 6 | tuensang
# Processing Record 34 of Set 6 | dikson
# Processing Record 35 of Set 6 | iqaluit
# Processing Record 36 of Set 6 | lutz
# Processing Record 37 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 6 | ozernovskiy
# Processing Record 39 of Set 6 | bubaque
# Processing Record 40 of Set 6 | acarau
# Processing Record 41 of Set 6 | shu
# Processing Record 42 of Set 6 | tuatapere
# Processing Record 43 of Set 6 | krivosheino
# Processing Record 44 of Set 6 | vila
# Processing Record 45 of Set 6 | coquimbo
# Processing Record 46 of Set 6 | touros
# Processing Record 47 of Set 6 | havelock
# Processing Record 48 of Set 6 | canico
# Processing Record 49 of Set 6 | fez
# Processing Record 50 of Set 6 | zyryanka
# Processing Record 1 of Set 7 | tiksi
# Processing Record 2 of Set 7 | bayangol
# Processing Record 3 of Set 7 | kasongo-lunda
# Processing Record 4 of Set 7 | mabaruma
# Processing Record 5 of Set 7 | chuy
# Processing Record 6 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 7 | beidao
# Processing Record 8 of Set 7 | port shepstone
# Processing Record 9 of Set 7 | praia
# Processing Record 10 of Set 7 | libreville
# Processing Record 11 of Set 7 | vanimo
# Processing Record 12 of Set 7 | kibala
# Processing Record 13 of Set 7 | faribault
# Processing Record 14 of Set 7 | ambovombe
# Processing Record 15 of Set 7 | qiongshan
# Processing Record 16 of Set 7 | baracoa
# Processing Record 17 of Set 7 | panaba
# Processing Record 18 of Set 7 | sabang
# Processing Record 19 of Set 7 | mingyue
# Processing Record 20 of Set 7 | hay river
# Processing Record 21 of Set 7 | kuching
# Processing Record 22 of Set 7 | kieta
# Processing Record 23 of Set 7 | leh
# Processing Record 24 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 7 | la ciotat
# Processing Record 26 of Set 7 | dingle
# Processing Record 27 of Set 7 | emerald
# Processing Record 28 of Set 7 | kamensk-uralskiy
# Processing Record 29 of Set 7 | troina
# Processing Record 30 of Set 7 | komsomolskiy
# Processing Record 31 of Set 7 | zeerust
# Processing Record 32 of Set 7 | jalu
# Processing Record 33 of Set 7 | belyy
# Processing Record 34 of Set 7 | dekernes
# Processing Record 35 of Set 7 | flin flon
# Processing Record 36 of Set 7 | montepuez
# Processing Record 37 of Set 7 | kununurra
# Processing Record 38 of Set 7 | bissora
# Processing Record 39 of Set 7 | baruun-urt
# Processing Record 40 of Set 7 | kaeo
# Processing Record 41 of Set 7 | santa cruz
# Processing Record 42 of Set 7 | saint-felicien
# Processing Record 43 of Set 7 | yulara
# Processing Record 44 of Set 7 | nanning
# Processing Record 45 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 7 | batagay-alyta
# Processing Record 48 of Set 7 | wana
# Processing Record 49 of Set 7 | harper
# Processing Record 50 of Set 7 | chiang mai
# Processing Record 1 of Set 8 | menongue
# Processing Record 2 of Set 8 | port blair
# Processing Record 3 of Set 8 | lata
# Processing Record 4 of Set 8 | filadelfia
# Processing Record 5 of Set 8 | petropavlovka
# Processing Record 6 of Set 8 | husavik
# Processing Record 7 of Set 8 | la peca
# Processing Record 8 of Set 8 | agua verde
# Processing Record 9 of Set 8 | mitsamiouli
# Processing Record 10 of Set 8 | ucluelet
# Processing Record 11 of Set 8 | olaine
# Processing Record 12 of Set 8 | rawson
# Processing Record 13 of Set 8 | high level
# Processing Record 14 of Set 8 | klaksvik
# Processing Record 15 of Set 8 | pangnirtung
# Processing Record 16 of Set 8 | fornosovo
# Processing Record 17 of Set 8 | marica
# Processing Record 18 of Set 8 | mbutuy
# Processing Record 19 of Set 8 | pesochenskiy
# Processing Record 20 of Set 8 | cherskiy
# Processing Record 21 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 8 | comodoro rivadavia
# Processing Record 23 of Set 8 | talavera
# Processing Record 24 of Set 8 | koutsouras
# Processing Record 25 of Set 8 | lavrentiya
# Processing Record 26 of Set 8 | werther
# Processing Record 27 of Set 8 | san andres
# Processing Record 28 of Set 8 | isla mujeres
# Processing Record 29 of Set 8 | mayaposi
# City not found. Skipping...
# Processing Record 30 of Set 8 | solnechnyy
# Processing Record 31 of Set 8 | bariadi
# Processing Record 32 of Set 8 | glenwood springs
# Processing Record 33 of Set 8 | hearst
# Processing Record 34 of Set 8 | jacareacanga
# Processing Record 35 of Set 8 | eureka
# Processing Record 36 of Set 8 | ghosi
# Processing Record 37 of Set 8 | belyy yar
# Processing Record 38 of Set 8 | miramar
# Processing Record 39 of Set 8 | lakes entrance
# Processing Record 40 of Set 8 | abnub
# Processing Record 41 of Set 8 | independence
# Processing Record 42 of Set 8 | mbandaka
# Processing Record 43 of Set 8 | aksay
# Processing Record 44 of Set 8 | khani
# Processing Record 45 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 8 | arlit
# Processing Record 47 of Set 8 | wuwei
# Processing Record 48 of Set 8 | qaqortoq
# Processing Record 49 of Set 8 | el balyana
# City not found. Skipping...
# Processing Record 50 of Set 8 | bodden town
# Processing Record 1 of Set 9 | urucara
# Processing Record 2 of Set 9 | tres arroyos
# Processing Record 3 of Set 9 | loudeac
# Processing Record 4 of Set 9 | goderich
# Processing Record 5 of Set 9 | port-gentil
# Processing Record 6 of Set 9 | fortuna
# Processing Record 7 of Set 9 | burica
# City not found. Skipping...
# Processing Record 8 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 9 | marzuq
# Processing Record 10 of Set 9 | plettenberg bay
# Processing Record 11 of Set 9 | siemiatycze
# Processing Record 12 of Set 9 | berea
# Processing Record 13 of Set 9 | vaitape
# Processing Record 14 of Set 9 | juegang
# Processing Record 15 of Set 9 | sangar
# Processing Record 16 of Set 9 | maglaj
# Processing Record 17 of Set 9 | lake cowichan
# Processing Record 18 of Set 9 | unecha
# Processing Record 19 of Set 9 | usva
# City not found. Skipping...
# Processing Record 20 of Set 9 | te anau
# Processing Record 21 of Set 9 | lowestoft
# Processing Record 22 of Set 9 | henties bay
# Processing Record 23 of Set 9 | racine
# Processing Record 24 of Set 9 | colesberg
# Processing Record 25 of Set 9 | londoko
# Processing Record 26 of Set 9 | sao joao da barra
# Processing Record 27 of Set 9 | urengoy
# Processing Record 28 of Set 9 | panzhihua
# Processing Record 29 of Set 9 | garowe
# Processing Record 30 of Set 9 | wagar
# Processing Record 31 of Set 9 | santa clara
# Processing Record 32 of Set 9 | karratha
# Processing Record 33 of Set 9 | bilgi
# Processing Record 34 of Set 9 | luena
# Processing Record 35 of Set 9 | yuncheng
# Processing Record 36 of Set 9 | kushmurun
# Processing Record 37 of Set 9 | waterloo
# Processing Record 38 of Set 9 | wukari
# Processing Record 39 of Set 9 | caramay
# Processing Record 40 of Set 9 | port hardy
# Processing Record 41 of Set 9 | grand-lahou
# Processing Record 42 of Set 9 | namatanai
# Processing Record 43 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 9 | katobu
# Processing Record 45 of Set 9 | miri
# Processing Record 46 of Set 9 | lorengau
# Processing Record 47 of Set 9 | bilma
# Processing Record 48 of Set 9 | aswan
# Processing Record 49 of Set 9 | irbeyskoye
# Processing Record 50 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 10 | truro
# Processing Record 2 of Set 10 | teya
# Processing Record 3 of Set 10 | ust-ilimsk
# Processing Record 4 of Set 10 | lagoa
# Processing Record 5 of Set 10 | callaway
# Processing Record 6 of Set 10 | san jose del guaviare
# Processing Record 7 of Set 10 | zvoristea
# Processing Record 8 of Set 10 | manzil tamim
# City not found. Skipping...
# Processing Record 9 of Set 10 | kudahuvadhoo
# Processing Record 10 of Set 10 | ngorongoro
# Processing Record 11 of Set 10 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 12 of Set 10 | aktas
# Processing Record 13 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 14 of Set 10 | alta gracia
# Processing Record 15 of Set 10 | mitu
# Processing Record 16 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 17 of Set 10 | rayadrug
# Processing Record 18 of Set 10 | samus
# Processing Record 19 of Set 10 | consolacion del sur
# Processing Record 20 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 10 | nueva loja
# Processing Record 22 of Set 10 | nisko
# Processing Record 23 of Set 10 | gornozavodsk
# Processing Record 24 of Set 10 | korla
# Processing Record 25 of Set 10 | nioro
# Processing Record 26 of Set 10 | skibotn
# Processing Record 27 of Set 10 | san patricio
# Processing Record 28 of Set 10 | selma
# Processing Record 29 of Set 10 | krasnoselkup
# Processing Record 30 of Set 10 | ambilobe
# Processing Record 31 of Set 10 | saint-augustin
# Processing Record 32 of Set 10 | lompoc
# Processing Record 33 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 34 of Set 10 | margate
# Processing Record 35 of Set 10 | dolinsk
# Processing Record 36 of Set 10 | idrinskoye
# Processing Record 37 of Set 10 | blackwater
# Processing Record 38 of Set 10 | moji das cruzes
# City not found. Skipping...
# Processing Record 39 of Set 10 | kayes
# Processing Record 40 of Set 10 | simao
# Processing Record 41 of Set 10 | fraserburgh
# Processing Record 42 of Set 10 | kaseda
# Processing Record 43 of Set 10 | la rioja
# Processing Record 44 of Set 10 | turan
# Processing Record 45 of Set 10 | pozega
# Processing Record 46 of Set 10 | vestmanna
# Processing Record 47 of Set 10 | araguacu
# Processing Record 48 of Set 10 | atar
# Processing Record 49 of Set 10 | santa maria
# Processing Record 50 of Set 10 | san martin
# Processing Record 1 of Set 11 | samarai
# Processing Record 2 of Set 11 | tena
# Processing Record 3 of Set 11 | kirkuk
# Processing Record 4 of Set 11 | nelson bay
# Processing Record 5 of Set 11 | hambantota
# Processing Record 6 of Set 11 | ilinge
# Processing Record 7 of Set 11 | alyangula
# Processing Record 8 of Set 11 | llangefni
# Processing Record 9 of Set 11 | broome
# Processing Record 10 of Set 11 | laurel
# Processing Record 11 of Set 11 | darab
# Processing Record 12 of Set 11 | kenora
# Processing Record 13 of Set 11 | isangel
# Processing Record 14 of Set 11 | saint-joseph
# Processing Record 15 of Set 11 | granada
# Processing Record 16 of Set 11 | lobito
# Processing Record 17 of Set 11 | kozhva
# Processing Record 18 of Set 11 | segezha
# Processing Record 19 of Set 11 | sorland
# Processing Record 20 of Set 11 | sobolevo
# Processing Record 21 of Set 11 | wattegama
# Processing Record 22 of Set 11 | ciudad del maiz
# Processing Record 23 of Set 11 | cochrane
# Processing Record 24 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 25 of Set 11 | karpogory
# Processing Record 26 of Set 11 | eltham
# Processing Record 27 of Set 11 | chokwe
# Processing Record 28 of Set 11 | batemans bay
# Processing Record 29 of Set 11 | potosi
# Processing Record 30 of Set 11 | whitehorse
# Processing Record 31 of Set 11 | aitape
# Processing Record 32 of Set 11 | tautira
# Processing Record 33 of Set 11 | shingu
# Processing Record 34 of Set 11 | belmonte
# Processing Record 35 of Set 11 | olga
# Processing Record 36 of Set 11 | radhan
# Processing Record 37 of Set 11 | mangrol
# Processing Record 38 of Set 11 | iracoubo
# Processing Record 39 of Set 11 | broken hill
# Processing Record 40 of Set 11 | vakhrushi
# Processing Record 41 of Set 11 | ciparay
# Processing Record 42 of Set 11 | karpathos
# Processing Record 43 of Set 11 | benguela
# Processing Record 44 of Set 11 | suez
# Processing Record 45 of Set 11 | olafsvik
# Processing Record 46 of Set 11 | roma
# Processing Record 47 of Set 11 | plouzane
# Processing Record 48 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 49 of Set 11 | machilipatnam
# Processing Record 50 of Set 11 | pilar
# Processing Record 1 of Set 12 | hongjiang
# Processing Record 2 of Set 12 | avera
# Processing Record 3 of Set 12 | anshun
# Processing Record 4 of Set 12 | pullman
# Processing Record 5 of Set 12 | necochea
# Processing Record 6 of Set 12 | mount gambier
# Processing Record 7 of Set 12 | libenge
# Processing Record 8 of Set 12 | okakarara
# Processing Record 9 of Set 12 | mokobeng
# Processing Record 10 of Set 12 | kharp
# Processing Record 11 of Set 12 | kabare
# Processing Record 12 of Set 12 | milici
# Processing Record 13 of Set 12 | marrakesh
# Processing Record 14 of Set 12 | belvidere
# Processing Record 15 of Set 12 | tazmalt
# Processing Record 16 of Set 12 | shakawe
# Processing Record 17 of Set 12 | novouzensk
# Processing Record 18 of Set 12 | bobrovytsya
# Processing Record 19 of Set 12 | ankang
# Processing Record 20 of Set 12 | vitim
# Processing Record 21 of Set 12 | dingzhou
# Processing Record 22 of Set 12 | pitimbu
# Processing Record 23 of Set 12 | preobrazheniye
# Processing Record 24 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 25 of Set 12 | yarmouth
# Processing Record 26 of Set 12 | tevaitoa
# Processing Record 27 of Set 12 | sitka
# Processing Record 28 of Set 12 | san quintin
# Processing Record 29 of Set 12 | rincon
# Processing Record 30 of Set 12 | westport
# Processing Record 31 of Set 12 | tottori
# Processing Record 32 of Set 12 | sayyan
# Processing Record 33 of Set 12 | kirakira
# Processing Record 34 of Set 12 | aklavik
# Processing Record 35 of Set 12 | sao filipe
# Processing Record 36 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 12 | iskateley
# Processing Record 38 of Set 12 | clyde river
# Processing Record 39 of Set 12 | rock sound
# Processing Record 40 of Set 12 | vila velha
# Processing Record 41 of Set 12 | vardo
# Processing Record 42 of Set 12 | beloha
# Processing Record 43 of Set 12 | mackenzie
# Processing Record 44 of Set 12 | teacapan
# Processing Record 45 of Set 12 | inta
# Processing Record 46 of Set 12 | sartell
# Processing Record 47 of Set 12 | cedral
# Processing Record 48 of Set 12 | san jose
# Processing Record 49 of Set 12 | rassvet
# Processing Record 50 of Set 12 | kalaleh
# Processing Record 1 of Set 13 | matadi
# Processing Record 2 of Set 13 | guanare
# Processing Record 3 of Set 13 | awjilah
# Processing Record 4 of Set 13 | mancio lima
# Processing Record 5 of Set 13 | ahipara
# Processing Record 6 of Set 13 | poronaysk
# Processing Record 7 of Set 13 | itaituba
# Processing Record 8 of Set 13 | yurla
# Processing Record 9 of Set 13 | srednekolymsk
# Processing Record 10 of Set 13 | nosy varika
# Processing Record 11 of Set 13 | tokur
# Processing Record 12 of Set 13 | calabozo
# Processing Record 13 of Set 13 | batticaloa
# Processing Record 14 of Set 13 | jinchengjiang
# City not found. Skipping...
# Processing Record 15 of Set 13 | gorahun
# Processing Record 16 of Set 13 | gao
# Processing Record 17 of Set 13 | barcelos
# Processing Record 18 of Set 13 | hanmer springs
# Processing Record 19 of Set 13 | lasa
# Processing Record 20 of Set 13 | americus
# Processing Record 21 of Set 13 | omboue
# Processing Record 22 of Set 13 | benoy
# Processing Record 23 of Set 13 | xichang
# Processing Record 24 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 13 | vrangel
# Processing Record 27 of Set 13 | trairi
# Processing Record 28 of Set 13 | tagusao
# Processing Record 29 of Set 13 | sivas
# Processing Record 30 of Set 13 | watrous
# Processing Record 31 of Set 13 | svetlyy
# Processing Record 32 of Set 13 | kelcyre
# Processing Record 33 of Set 13 | talnakh
# Processing Record 34 of Set 13 | vostok
# Processing Record 35 of Set 13 | harwich
# Processing Record 36 of Set 13 | ende
# Processing Record 37 of Set 13 | ciras
# City not found. Skipping...
# Processing Record 38 of Set 13 | nuuk
# Processing Record 39 of Set 13 | jumla
# Processing Record 40 of Set 13 | mantua
# Processing Record 41 of Set 13 | leshukonskoye
# Processing Record 42 of Set 13 | waw
# Processing Record 43 of Set 13 | spornoye
# Processing Record 44 of Set 13 | san policarpo
# Processing Record 45 of Set 13 | katherine
# Processing Record 46 of Set 13 | uptar
# Processing Record 47 of Set 13 | mvomero
# Processing Record 48 of Set 13 | saint-jean-port-joli
# Processing Record 49 of Set 13 | sault sainte marie
# Processing Record 50 of Set 13 | camacha
# Processing Record 1 of Set 14 | kasongo
# Processing Record 2 of Set 14 | juneau
# Processing Record 3 of Set 14 | waingapu
# Processing Record 4 of Set 14 | euclides da cunha
# Processing Record 5 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 6 of Set 14 | the valley
# Processing Record 7 of Set 14 | thinadhoo
# Processing Record 8 of Set 14 | bolobo
# Processing Record 9 of Set 14 | nagato
# Processing Record 10 of Set 14 | beroroha
# Processing Record 11 of Set 14 | vanavara
# Processing Record 12 of Set 14 | macduff
# Processing Record 13 of Set 14 | sattahip
# Processing Record 14 of Set 14 | havre
# Processing Record 15 of Set 14 | moerai
# Processing Record 16 of Set 14 | pozo colorado
# Processing Record 17 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 14 | hammerfest
# Processing Record 19 of Set 14 | walvis bay
# Processing Record 20 of Set 14 | waipawa
# Processing Record 21 of Set 14 | pavilosta
# Processing Record 22 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 23 of Set 14 | pringsewu
# Processing Record 24 of Set 14 | hit
# Processing Record 25 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 14 | padang
# Processing Record 27 of Set 14 | ulladulla
# Processing Record 28 of Set 14 | shaunavon
# Processing Record 29 of Set 14 | maragogi
# Processing Record 30 of Set 14 | faya
# Processing Record 31 of Set 14 | rexburg
# Processing Record 32 of Set 14 | guaimaro
# Processing Record 33 of Set 14 | manica
# Processing Record 34 of Set 14 | krasnoborsk
# Processing Record 35 of Set 14 | chaa-khol
# City not found. Skipping...
# Processing Record 36 of Set 14 | chacabuco
# Processing Record 37 of Set 14 | jinchang
# Processing Record 38 of Set 14 | eenhana
# Processing Record 39 of Set 14 | lincoln
# Processing Record 40 of Set 14 | mnogovershinnyy
# Processing Record 41 of Set 14 | kantang
# Processing Record 42 of Set 14 | linares
# Processing Record 43 of Set 14 | abu samrah
# Processing Record 44 of Set 14 | port augusta
# Processing Record 45 of Set 14 | tambura
# Processing Record 46 of Set 14 | ariquemes
# Processing Record 47 of Set 14 | nkhata bay
# Processing Record 48 of Set 14 | dutlwe
# Processing Record 49 of Set 14 | gazojak
# Processing Record 50 of Set 14 | los andes
# Processing Record 1 of Set 15 | bagotville
# Processing Record 2 of Set 15 | tieling
# Processing Record 3 of Set 15 | sechura
# Processing Record 4 of Set 15 | gavle
# Processing Record 5 of Set 15 | mont-dore
# Processing Record 6 of Set 15 | sadovoye
# Processing Record 7 of Set 15 | ambon
# Processing Record 8 of Set 15 | almeirim
# Processing Record 9 of Set 15 | merauke
# Processing Record 10 of Set 15 | pogradec
# Processing Record 11 of Set 15 | chapais
# Processing Record 12 of Set 15 | hirara
# Processing Record 13 of Set 15 | viedma
# Processing Record 14 of Set 15 | almoloya
# Processing Record 15 of Set 15 | uroteppa
# City not found. Skipping...
# Processing Record 16 of Set 15 | canandaigua
# Processing Record 17 of Set 15 | shediac
# Processing Record 18 of Set 15 | jiwani
# Processing Record 19 of Set 15 | sistranda
# Processing Record 20 of Set 15 | lovrenc na pohorju
# Processing Record 21 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 22 of Set 15 | saint-pierre
# Processing Record 23 of Set 15 | linguere
# Processing Record 24 of Set 15 | rome
# Processing Record 25 of Set 15 | kirkcudbright
# Processing Record 26 of Set 15 | opuwo
# Processing Record 27 of Set 15 | rodrigues alves
# Processing Record 28 of Set 15 | hobyo
# Processing Record 29 of Set 15 | luanda
# Processing Record 30 of Set 15 | saskatoon
# Processing Record 31 of Set 15 | atasu
# Processing Record 32 of Set 15 | raudeberg
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 675

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Port Alfred -33.5906   26.8910     68.23        55          89
# 1          Tarakan   3.3000  117.6333     81.05        76          94
# 2            Airai  -8.9266  125.4092     63.97        93         100
# 3     Punta Arenas -53.1500  -70.9167     51.91        71          40
# 4            Vaini -21.2000 -175.2000     77.16        94          40
# 5  Haines Junction  60.7522 -137.5108      4.03        99          99
# 6          Rikitea -23.1203 -134.9692     78.55        70         100
# 7     Kruisfontein -34.0033   24.7314     67.89        44          87
# 8          Mataura -46.1927  168.8643     55.18        68           0
# 9        Hithadhoo  -0.6000   73.0833     81.90        75          47
#
#    Wind Speed Country       Description
# 0       13.27      ZA   overcast clouds
# 1        9.08      ID   overcast clouds
# 2        0.74      TL   overcast clouds
# 3        4.61      CL  scattered clouds
# 4        2.30      TO     moderate rain
# 5        1.07      CA   overcast clouds
# 6       11.01      PF   overcast clouds
# 7       14.32      ZA   overcast clouds
# 8        1.30      NZ         clear sky
# 9       13.33      MV  scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Description"] 

# Recreate the DataFrame by using the new column order

city_data_df = city_data_df[new_column_order]


# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Port Alfred      ZA -33.5906   26.8910     68.23        55          89
# 1          Tarakan      ID   3.3000  117.6333     81.05        76          94
# 2            Airai      TL  -8.9266  125.4092     63.97        93         100
# 3     Punta Arenas      CL -53.1500  -70.9167     51.91        71          40
# 4            Vaini      TO -21.2000 -175.2000     77.16        94          40
# 5  Haines Junction      CA  60.7522 -137.5108      4.03        99          99
# 6          Rikitea      PF -23.1203 -134.9692     78.55        70         100
# 7     Kruisfontein      ZA -34.0033   24.7314     67.89        44          87
# 8          Mataura      NZ -46.1927  168.8643     55.18        68           0
# 9        Hithadhoo      MV  -0.6000   73.0833     81.90        75          47
#
#    Wind Speed       Description
# 0       13.27   overcast clouds
# 1        9.08   overcast clouds
# 2        0.74   overcast clouds
# 3        4.61  scattered clouds
# 4        2.30     moderate rain
# 5        1.07   overcast clouds
# 6       11.01   overcast clouds
# 7       14.32   overcast clouds
# 8        1.30         clear sky
# 9       13.33  scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
